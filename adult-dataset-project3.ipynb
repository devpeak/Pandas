# %% [markdown]
# 1. How to fetch random samples from the dataset?
# 2. isin
# 3. unique
# 4. dropna
# 5. replace
# 6. duplicated
# 7. drop_duplicates
# 8. astype
# 9. apply
# 10. what is univariate analysis?
# 11. What is Bivarariate analysis?
# 12. Memory Optimization

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('adult.csv')

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# # 1. Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# # 2. Display last 10 rows of The Dataset

# %%
df.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %% [markdown]
# # 3. Find shape of our DataSet (Number of Rows and Number of Columns)

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.shape[0]
# Out:
# 48842

# %%
df.shape[1]
# Out:
# 15

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 15

# %% [markdown]
# # 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# # 5.Fetch Random Samples From the Dataset(50%)

# %%
df.sample(frac = 0.50) #50% of random data from dataset
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 42625   23    Private  100345     Bachelors               13
# 41103   34    Private  100950     Assoc-voc               11
# 2086    19    Private   37688       HS-grad                9
# 21813   42  State-gov  117583     Doctorate               16
# 33015   27    Private  116207           9th                5
# ...    ...        ...     ...           ...              ...
# 15850   19    Private  158603       HS-grad                9
# 32785   30    Private   86808     Bachelors               13
# 5290    23    Private   39551       HS-grad                9
# 32935   21    Private  283757  Some-college               10
# 40523   25    Private  110138       HS-grad                9
#
#            marital-status         occupation    relationship   race  gender  \
# 42625       Never-married              Sales       Own-child  White    Male
# 41103       Never-married     Prof-specialty       Unmarried  White  Female
# ...

# %%
df.sample(frac = 0.50 , random_state = 10)
# Out:
#        age    workclass  fnlwgt     education  educational-num  \
# 28113   34      Private  339142       HS-grad                9
# 40486   69      Private  130413     Bachelors               13
# 45549   26    Local-gov   72594  Some-college               10
# 3173    57    Local-gov  212303       Masters               14
# 46828   18      Private  137646          11th                7
# ...    ...          ...     ...           ...              ...
# 13121   26  Federal-gov  269353     Assoc-voc               11
# 6802    46      Private   45857       HS-grad                9
# 23454   64            ?  140237     Preschool                1
# 24541   25      Private  187540  Some-college               10
# 5206    30      Private  247328       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 28113           Separated  Handlers-cleaners      Unmarried  White  Female
# ...

# %%
#on initializing random_state = some integer , it prohibits random values

# %%
data  = df.sample(frac = 0.50 , random_state = 69)

# %%
data
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 21272   29           Private  266043           9th                5
# 20218   39           Private  191841    Assoc-acdm               12
# 12143   31           Private  143083       Masters               14
# 35891   22           Private  340543       HS-grad                9
# 31261   29                 ?  189765       5th-6th                3
# ...    ...               ...     ...           ...              ...
# 40957   29         State-gov  159782       Masters               14
# 3628    34  Self-emp-not-inc  180607       HS-grad                9
# 44024   42           Private  182108     Bachelors               13
# 11140   19           Private   70505  Some-college               10
# 13120   32           Private  252168  Some-college               10
#
#               marital-status        occupation   relationship   race  gender  \
# ...

# %% [markdown]
# # 6. Check Null Values In The DataSet

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.isnull().sum(axis = 1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    0
# Length: 48842, dtype: int64

# %%
df.isnull().sum(axis = 0)
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 7. Perform Data Cleaning [Replace '?' with NaN]

# %%
df.tail(20)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 48822   41                 ?  202822       HS-grad                9
# 48823   72                 ?  129912       HS-grad                9
# 48824   45         Local-gov  119199    Assoc-acdm               12
# 48825   31           Private  199655       Masters               14
# 48826   39         Local-gov  111499    Assoc-acdm               12
# 48827   37           Private  198216    Assoc-acdm               12
# 48828   43           Private  260761       HS-grad                9
# 48829   65  Self-emp-not-inc   99359   Prof-school               15
# 48830   43         State-gov  255835  Some-college               10
# 48831   43  Self-emp-not-inc   27242  Some-college               10
# 48832   32           Private   34066          10th                6
# 48833   43           Private   84661     Assoc-voc               11
# 48834   32           Private  116138       Masters               14
# ...

# %%
#let's check how many columns have '?'

# %%
df.isin(['?'])
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False       True   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
df.isin(['?']).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
import numpy as np

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df['workclass'].replace('?',np.nan)
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 4                 NaN
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: workclass, Length: 48842, dtype: object

# %%
df['workclass'] = df['workclass'].replace('?',np.nan)

# %%
df['workclass']
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 4                 NaN
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: workclass, Length: 48842, dtype: object

# %%
df['occupation'] = df['occupation'].replace('?',np.nan)

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df['native-country'] = df['native-country'].replace('?',np.nan)

# %%
df['native-country']
# Out:
# 0        United-States
# 1        United-States
# 2        United-States
# 3        United-States
# 4        United-States
#              ...
# 48837    United-States
# 48838    United-States
# 48839    United-States
# 48840    United-States
# 48841    United-States
# Name: native-country, Length: 48842, dtype: object

# %%
df.isin(['?']).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.isnull().sum() #as all '?' become null value
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation            0
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cbar = False)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [raw]
# It becomes dark because dataframe contain null values.

# %% [markdown]
# # 8. Drop all the Missing Values

# %% [raw]
# let's check missing values %

# %%
per_missing = df.isnull().sum()*100/len(df)

# %%
per_missing
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         0.000000
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
df.dropna(how = 'any',inplace = True)
df.shape
# Out:
# (45232, 15)

# %%
print(48842-45222) #dropped rows
# Out:
# 3620

# %% [raw]
# The dropna() method removes the rows that contains NULL values.
#
# The dropna() method returns a new DataFrame object unless the inplace parameter is set to True, in that case the dropna() method does the removing in the original DataFrame instead.
#
#
# how
# 'all'
# 'any'
# Optional, default 'any'. Specifies whether to remove the row or column when ALL values are NULL, or if ANY value is NULL.

# %% [markdown]
# # 9. Check For Duplicate Date and Drop Them

# %%
dup = df.duplicated().any()

# %%
print('Are there any duplicated value in the data ?',dup)
# Out:
# Are there any duplicated value in the data ? True

# %%
#yes there is , so lets drop them

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (45185, 15)

# %%
45222-45175
# Out:
# 47

# %%
#47 are dropped

# %% [markdown]
# # 10. Get overall statistics about the DataFrame

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45185.000000  4.518500e+04     45185.000000  45185.000000
# mean      38.552042  1.897444e+05        10.118734   1102.332256
# std       13.216920  1.056502e+05         2.551904   7509.436666
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.174000e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45185.000000    45185.000000
# mean      88.667965       40.939847
# std      405.113923       12.009156
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [raw]
# DATAFRAME contains 25% value that are below 28 in AGE COLUMN
# DATAFRAME contains 50% value that are below 37 in AGE COLUMN
#
# if we see in capital-gain and capital loss 75% value are below or equal to 0 , so let's drop these columns.

# %%
df.describe(include ='all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   45185.000000     45185  4.518500e+04     45185     45185.000000
# unique           NaN         8           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33262           NaN     14772              NaN
# mean       38.552042       NaN  1.897444e+05       NaN        10.118734
# std        13.216920       NaN  1.056502e+05       NaN         2.551904
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.174000e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783120e+05       NaN        10.000000
# 75%        47.000000       NaN  2.379030e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status    occupation relationship   race gender  \
# ...

# %%
#droping education and educational-num

# %%
data['education'].unique()
# Out:
# array(['9th', 'Assoc-acdm', 'Masters', 'HS-grad', '5th-6th',
#        'Some-college', '7th-8th', 'Bachelors', 'Assoc-voc', '11th',
#        '10th', 'Doctorate', 'Prof-school', '1st-4th', '12th', 'Preschool'],
#       dtype=object)

# %%
data['educational-num'].unique()
# Out:
# array([ 5, 12, 14,  9,  3, 10,  4, 13, 11,  7,  6, 16, 15,  2,  8,  1],
#       dtype=int64)

# %% [markdown]
# # Drop The Columns educational-num,capital-gain and capital-loss

# %% [raw]
# df.drop(['capital-gain','capital-loss','educational-num'],axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [raw]
# Univariate analysis is perhaps the simplest form of statistical analysis. Like other forms of statistics, it can be inferential or descriptive. The key fact is that only one variable is involved.
#
# Univariate analysis can yield misleading results in cases in which multivariate analysis is more appropriate.

# %% [markdown]
# # 12. WHAT is the distribution of Age column ?

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
df['age'].describe() #to know min and max , average
# Out:
# count    45185.000000
# mean        38.552042
# std         13.216920
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
#for distribution -> use histogram

# %%
df['age'].hist()
# Out:
# <AxesSubplot:>

# %%
#analysis: person of age between 17 -48 are maximum

# %% [markdown]
# # 13. Find Total Number Of Person Having Age Between 17 to 48 (Inclusive) Using Between Method

# %%
df[df['age'] >= 17 & df['age']<=48]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22032/2804498860.py in <module>
# ----> 1 df[df['age'] >= 17 & df['age']<=48]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# (for 2 or more than 2 conditions we have to put parenthesis)

# %%
len(df[(df['age']>=17) & (df['age']<=48)])
# Out:
# 34868

# %%
sum((df['age']>=17) & (df['age']<=48))
# Out:
# 34868

# %%
sum(df['age'].between(17,48)) #both are inclusive
# Out:
# 34868

# %% [markdown]
# # What is The Distribution of Workclass Column ?

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
df['workclass'].describe()
# Out:
# count       45185
# unique          8
# top       Private
# freq        33262
# Name: workclass, dtype: object

# %%
df['workclass'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10))
df['workclass'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # VVI
#
# plt.figure(figsize=(15,15))

# %% [markdown]
# # 15 . How Many Person Having Bachelors or Masteer Degree ?

# %%
df['education'].unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', '5th-6th',
#        'Assoc-voc', '9th', 'Doctorate', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
len(df[(df['education'] == 'Bachelors') | (df['education'] =='Masters')])
# Out:
# 10072

# %%
sum((df['education'] == 'Bachelors') | (df['education'] =='Masters'))
# Out:
# 10072

# %%
filter1 = df['education'] == 'Bachelors'
filter2 = df['education'] == 'Masters'

# %%
df[filter1|filter2]
# Out:
#        age    workclass  fnlwgt  education      marital-status  \
# 11      36  Federal-gov  212465  Bachelors  Married-civ-spouse
# 15      43      Private  346189    Masters  Married-civ-spouse
# 20      34      Private  107914  Bachelors  Married-civ-spouse
# 23      25      Private  220931  Bachelors       Never-married
# 24      25      Private  205947  Bachelors  Married-civ-spouse
# ...    ...          ...     ...        ...                 ...
# 48817   34      Private  160216  Bachelors       Never-married
# 48819   38      Private  139180  Bachelors            Divorced
# 48825   31      Private  199655    Masters            Divorced
# 48834   32      Private  116138    Masters       Never-married
# 48835   53      Private  321865    Masters  Married-civ-spouse
#
#             occupation   relationship                race  gender  \
# 11        Adm-clerical        Husband               White    Male
# 15     Exec-managerial        Husband               White    Male
# ...

# %%
sum(filter1 | filter2)
# Out:
# 10072

# %%
#2nd Method

# %%
df['education'].isin(['Bachelors','Masters'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 5        False
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Name: education, Length: 45185, dtype: bool

# %%
sum(df['education'].isin(['Bachelors','Masters']))
# Out:
# 10072
